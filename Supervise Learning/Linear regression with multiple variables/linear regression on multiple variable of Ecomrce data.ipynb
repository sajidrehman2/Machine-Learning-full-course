# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers=pd.read_csv("Ecommerce Customers.unknown")

# %%
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
customers.describe().T
# Out:
#                       count        mean        std         min         25%  \
# Avg. Session Length   500.0   33.053194   0.992563   29.532429   32.341822
# Time on App           500.0   12.052488   0.994216    8.508152   11.388153
# Time on Website       500.0   37.060445   1.010489   33.913847   36.349257
# Length of Membership  500.0    3.533462   0.999278    0.269901    2.930450
# Yearly Amount Spent   500.0  499.314038  79.314782  256.670582  445.038277
#
#                              50%         75%         max
# Avg. Session Length    33.082008   33.711985   36.139662
# Time on App            11.983231   12.753850   15.126994
# Time on Website        37.069367   37.716432   40.005182
# Length of Membership    3.533975    4.126502    6.922689
# Yearly Amount Spent   498.887875  549.313828  765.518462

# %%
# time on website vs yearly amount spent
sns.jointplot(x='Time on Website', y='Yearly Amount Spent', data=customers, alpha=0.5)

# %%
customers.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns to plot against 'Yearly Amount Spent'
columns_to_plot = ['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']

# Set up the figure and axes for subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 5))

# Flatten the axes array for easy indexing
axes = axes.flatten()

# Loop through the columns and plot each one
for i, column in enumerate(columns_to_plot):
    sns.jointplot(x=column, y='Yearly Amount Spent', data=customers, ax=axes[i], alpha=0.5)

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SAJID\AppData\Local\Temp\ipykernel_5948\3308359730.py:15: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sns.jointplot(x=column, y='Yearly Amount Spent', data=customers, ax=axes[i], alpha=0.5)
# C:\Users\SAJID\AppData\Local\Temp\ipykernel_5948\3308359730.py:15: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sns.jointplot(x=column, y='Yearly Amount Spent', data=customers, ax=axes[i], alpha=0.5)
# C:\Users\SAJID\AppData\Local\Temp\ipykernel_5948\3308359730.py:15: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sns.jointplot(x=column, y='Yearly Amount Spent', data=customers, ax=axes[i], alpha=0.5)
# C:\Users\SAJID\AppData\Local\Temp\ipykernel_5948\3308359730.py:15: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sns.jointplot(x=column, y='Yearly Amount Spent', data=customers, ax=axes[i], alpha=0.5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set up the figure with subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Plot for 'Avg. Session Length'
sns.scatterplot(x='Avg. Session Length', y='Yearly Amount Spent', data=customers, ax=axes[0, 0], alpha=0.5)

# Plot for 'Time on App'
sns.scatterplot(x='Time on App', y='Yearly Amount Spent', data=customers, ax=axes[0, 1], alpha=0.5)

# Plot for 'Time on Website'
sns.scatterplot(x='Time on Website', y='Yearly Amount Spent', data=customers, ax=axes[1, 0], alpha=0.5)

# Plot for 'Length of Membership'
sns.scatterplot(x='Length of Membership', y='Yearly Amount Spent', data=customers, ax=axes[1, 1], alpha=0.5)

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set up the figure with subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Plot for 'Avg. Session Length'
sns.scatterplot(x='Avg. Session Length', y='Yearly Amount Spent', data=customers, ax=axes[0, 0], alpha=0.5)

# Plot for 'Time on App'
sns.scatterplot(x='Time on App', y='Yearly Amount Spent', data=customers, ax=axes[0, 1], alpha=0.5)

# Plot for 'Time on Website'
sns.scatterplot(x='Time on Website', y='Yearly Amount Spent', data=customers, ax=axes[1, 0], alpha=0.5)

# Plot for 'Length of Membership'
sns.scatterplot(x='Length of Membership', y='Yearly Amount Spent', data=customers, ax=axes[1, 1], alpha=0.5)

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
customers.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set up the figure with subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Plot for 'Avg. Session Length'
sns.scatterplot(x='Avg. Session Length', y='Yearly Amount Spent', data=customers, ax=axes[0, 0], alpha=0.5)
axes[0, 0].set_title('Avg. Session Length vs Yearly Amount Spent')

# Plot for 'Time on App'
sns.scatterplot(x='Time on App', y='Yearly Amount Spent', data=customers, ax=axes[0, 1], alpha=0.5)
axes[0, 1].set_title('Time on App vs Yearly Amount Spent')

# Plot for 'Time on Website'
sns.scatterplot(x='Time on Website', y='Yearly Amount Spent', data=customers, ax=axes[1, 0], alpha=0.5)
axes[1, 0].set_title('Time on Website vs Yearly Amount Spent')

# Plot for 'Length of Membership'
sns.scatterplot(x='Length of Membership', y='Yearly Amount Spent', data=customers, ax=axes[1, 1], alpha=0.5)
axes[1, 1].set_title('Length of Membership vs Yearly Amount Spent')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
relavent_columns=['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership', 'Yearly Amount Spent']
corrlation_matrix=customers[relavent_columns].corr()
Yearly_amount_correlation=corrlation_matrix['Yearly Amount Spent']
print(Yearly_amount_correlation)
# Out:
# Avg. Session Length     0.355088
# Time on App             0.499328
# Time on Website        -0.002641
# Length of Membership    0.809084
# Yearly Amount Spent     1.000000
# Name: Yearly Amount Spent, dtype: float64
# C:\Users\SAJID\AppData\Local\Temp\ipykernel_4068\782621901.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrlation_matrix=customers[relavent_columns].corr()

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# Create a temporary categorical column with random values
customers['Random Category'] = np.random.choice(['Category 1', 'Category 2', 'Category 3', 'Category 4'], size=len(customers))

# Plot the pairplot with mixed colors
sns.pairplot(customers,
             kind='scatter',
             plot_kws={'alpha': 0.4},
             diag_kind='kde',
             hue='Random Category',  # Use the random category for mixed colors
             palette='husl')  # Choose a color palette

plt.show()

# Optionally, drop the temporary column after plotting
customers.drop('Random Category', axis=1, inplace=True)

# %%
# length of membership vs yearly amount spent
sns.lmplot(x='Length of Membership', 
           y='Yearly Amount Spent', 
           data=customers,
           scatter_kws={'alpha':0.3},
          line_kws={'color': 'red'})

# %% [markdown]
# # Splitting the data
# X are the predictores, and y is the output. What we want to do is create a model that will take in the values in the X variable and predict y with a linear regression algorithm. We will use the SciKit Learn library to create the model.

# %%
from sklearn.model_selection import train_test_split

# %%
customers.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
X=customers[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]
y=customers['Yearly Amount Spent']

# %%
X.head()
y.head()
# Out:
# 0    587.951054
# 1    392.204933
# 2    487.547505
# 3    581.852344
# 4    599.406092
# Name: Yearly Amount Spent, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %% [markdown]
# # Training the Model with multivariable regression using Scikit Learn
# In this section, we create the model and feed the training data to it. This model will tell us which input has the biggest impact in the output (yearly expenditure). As the plots suggested, we find that the most important coefficient is that of the "Length of Membership" predictor, followed by the 'Time on App' and the 'Avg. Session Length'. The time on website does not seem to be an important factor to the amount a customer spends per year.

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([25.72425621, 38.59713548,  0.45914788, 61.67473243])

# %%
cdf=pd.DataFrame(lm.coef_,X.columns,columns=['Coef']) # the lenght of member is high correlated with yearly amount spend
print(cdf)
# Out:
#                            Coef
# Avg. Session Length   25.724256
# Time on App           38.597135
# Time on Website        0.459148
# Length of Membership  61.674732

# %% [markdown]
# # Predicting Test Data
# Now that the model is trained, we should be able to use it to make our predictions and evaluate our model. The scatter plot below plots the actual y values to the model's predictions. The model seems to behave accurately.

# %%
predictions=lm.predict(X_test)

# %%
sns.scatterplot(x=predication,y=y_test)
plt.ylabel("predication")
plt.title("predication vs Yearly Amount Spent")
# Out:
# Text(0.5, 1.0, 'predication vs Yearly Amount Spent')

# %%
# Plot actual values
sns.scatterplot(x=y_test, y=y_test, color='green', label='Actual Values')

# Plot predicted values
sns.scatterplot(x=predictions, y=y_test, color='red', label='Predicted Values')

# Add labels and title
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Prediction vs Yearly Amount Spent")
plt.legend()  # Add a legend to differentiate between the actual and predicted values

plt.show()

# %% [markdown]
# # Evaluation of the model

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
print('Mean Absolute Error:',mean_absolute_error(y_test, predictions))
print('Mean Squared Error:',mean_squared_error(y_test, predictions))
print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 8.426091641432052
# Mean Squared Error: 103.91554136503235
# Root Mean Squared Error: 10.193897260863107

# %% [markdown]
# ## Residuals
# Distribution plot of the residuals of the model's predictions. They should be normally distributed.mm

# %%
residuals = y_test-predictions
sns.distplot(residuals, bins=30)
# Out:
# C:\Users\SAJID\AppData\Local\Temp\ipykernel_4068\339810671.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, bins=30)
# <Axes: xlabel='Yearly Amount Spent', ylabel='Density'>

# %%
import pylab 
import scipy.stats as stats

stats.probplot(residuals, dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# # Conclusion
# It can be tricky to interpret the information in this analysis. According to the model, the most significant factor for clients is not the time spent on the app or website, but their length of membership. However, of the two predictors (desktop vs app), the app has the strongest influence by far. In fact, the time spent on the desktop website does not seem to have any correlation at all! In other words, according to the data, the amount of time that the customer spends on the desktop website has almost nothing to do with the amount of money they will spend.
#
# We could interpret this in two different ways. Firstly, this could mean that the desktop website needs more work to make its visitors buy more. Secondly, it could mean that people tend to be more influenced by mobile applications of online stores than by desktop websites. So maybe efforts should be directed towards taking advantage of this fact. Indeed, the interpretation of this information requires expertise in the online marketing sphere. Our analysis and our model, however, does a very good job in weighting the predictors importance.
