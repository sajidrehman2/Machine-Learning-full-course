# %% [markdown]
# # About Dataset
# The car company wants to enter a new market and needs an estimation of exactly which variables affect the car prices.
# The goal is:
#
# Which variables are significant in predicting the price of a car
# How well do those variables describe the price of a car

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("scrap price.csv")

# %%
df.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'symboling', 'name', 'fueltypes', 'aspiration', 'doornumbers',
#        'carbody', 'drivewheels', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
relevant_columns=['ID', 'symboling', 'name', 'fueltypes', 'aspiration', 'doornumbers',
       'carbody', 'drivewheels', 'enginelocation', 'wheelbase', 'carlength',
       'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
       'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
       'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']
relevant_matrix=df[relevant_columns].corr()
correlation_with_price=relevant_matrix["price"]
print(correlation_with_price)
# Out:
# ID                 -0.109093
# symboling          -0.079978
# wheelbase           0.577816
# carlength           0.682920
# carwidth            0.759325
# carheight           0.119336
# curbweight          0.835305
# enginesize          0.874145
# boreratio           0.553173
# stroke              0.079443
# compressionratio    0.067984
# horsepower          0.808139
# peakrpm            -0.085267
# citympg            -0.685751
# highwaympg         -0.697599
# price               1.000000
# Name: price, dtype: float64
# C:\Users\SAJID\AppData\Local\Temp\ipykernel_7844\913445075.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   relevant_matrix=df[relevant_columns].corr()

# %%
import pandas as pd

# Example correlation series
correlation_series = pd.Series({
    'ID': -0.109093,
    'symboling': -0.079978,
    'wheelbase': 0.577816,
    'carlength': 0.682920,
    'carwidth': 0.759325,
    'carheight': 0.119336,
    'curbweight': 0.835305,
    'enginesize': 0.874145,
    'boreratio': 0.553173,
    'stroke': 0.079443,
    'compressionratio': 0.067984,
    'horsepower': 0.808139,
    'peakrpm': -0.085267,
    'citympg': -0.685751,
    'highwaympg': -0.697599,
    'price': 1.000000
})

# Remove 'price' itself from the list
correlation_series = correlation_series.drop('price')

# Select the columns with strong correlation (absolute correlation > 0.5)
strong_correlations = correlation_series[correlation_series.abs() > 0.5]

# Sort by the correlation values
strong_correlations = strong_correlations.sort_values(ascending=False)

print(strong_correlations)
# Out:
# enginesize    0.874145
# curbweight    0.835305
# horsepower    0.808139
# carwidth      0.759325
# carlength     0.682920
# wheelbase     0.577816
# boreratio     0.553173
# citympg      -0.685751
# highwaympg   -0.697599
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Example correlation series (replace with actual values)
correlation_series = pd.Series({
    'ID': -0.109093,
    'symboling': -0.079978,
    'wheelbase': 0.577816,
    'carlength': 0.682920,
    'carwidth': 0.759325,
    'carheight': 0.119336,
    'curbweight': 0.835305,
    'enginesize': 0.874145,
    'boreratio': 0.553173,
    'stroke': 0.079443,
    'compressionratio': 0.067984,
    'horsepower': 0.808139,
    'peakrpm': -0.085267,
    'citympg': -0.685751,
    'highwaympg': -0.697599,
    'price': 1.000000
})

# Remove 'price' itself
correlation_series = correlation_series.drop('price')

# Select the columns with strong correlation (absolute correlation > 0.5)
strong_correlations = correlation_series[correlation_series.abs() > 0.5]

# Sort by the correlation values
strong_correlations = strong_correlations.sort_values(ascending=False)

# Plotting the correlations using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=strong_correlations.index, y=strong_correlations.values, palette="coolwarm")
plt.title("Correlation of Features with Price")
plt.ylabel("Correlation Coefficient")
plt.xlabel("Features")
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Replace the column names with the most correlated ones
sns.scatterplot(x="enginesize", y="price", data=df, ax=axes[0, 0], alpha=0.5)
sns.scatterplot(x="curbweight", y="price", data=df, ax=axes[0, 1], alpha=0.5)
sns.scatterplot(x="horsepower", y="price", data=df, ax=axes[1, 0], alpha=0.5)
sns.scatterplot(x="citympg", y="price", data=df, ax=axes[1, 1], alpha=0.5)

plt.tight_layout()
plt.show()

# %%
sns.lmplot(x="enginesize",
          y="price",
          data=df,
          scatter_kws={'alpha':0.5},
          line_kws={"color":"red"})

# %%
sns.lmplot(x="curbweight",
          y="price",
          data=df,
          scatter_kws={'alpha':0.5},
          line_kws={"color":"red"})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a list of the most correlated columns
correlated_columns = ['enginesize', 'curbweight', 'horsepower', 'citympg']  # Add other columns as needed

# Melt the dataframe for easy plotting with FacetGrid
df_melt = df.melt(id_vars='price', value_vars=correlated_columns, var_name='Feature', value_name='Value')

# Use FacetGrid to plot multiple lmplot-style graphs
g = sns.FacetGrid(df_melt, col="Feature", col_wrap=2, height=4, aspect=1.5)

# Map a scatter plot and regression line to each plot
g.map(sns.regplot, "Value", "price", scatter_kws={'alpha': 0.5}, line_kws={"color": "red"})

# Add titles and adjust layout
g.set_axis_labels("Feature Value", "Price")
g.fig.tight_layout()
plt.show()

# %%
X=df[['enginesize', 'curbweight', 'horsepower', 'citympg', 'highwaympg', 'carwidth', 'carlength', 'wheelbase']]

y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 82.71257938,   1.4845853 ,  39.62177545, -26.8612154 ,
#        -83.30305648, 826.5258573 , -39.11107881,  22.49652147])

# %%
cdf=pd.DataFrame(lm.coef_,X.columns,columns=['Coef']) # the lenght of member is high correlated with yearly amount spend
print(cdf)
# Out:
#                   Coef
# enginesize   82.712579
# curbweight    1.484585
# horsepower   39.621775
# citympg     -26.861215
# highwaympg  -83.303056
# carwidth    826.525857
# carlength   -39.111079
# wheelbase    22.496521

# %%
predictions=lm.predict(X_test)

# %%
# Plot actual values
sns.scatterplot(x=y_test, y=y_test, color='green', label='Actual Values')

# Plot predicted values
sns.scatterplot(x=predictions, y=y_test, color='red', label='Predicted Values')

# Add labels and title
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Prediction vs Price")
plt.legend()  # Add a legend to differentiate between the actual and predicted values

plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
print('Mean Absolute Error:',mean_absolute_error(y_test, predictions))
print('Mean Squared Error:',mean_squared_error(y_test, predictions))
print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 2858.288408184712
# Mean Squared Error: 16391380.714222258
# Root Mean Squared Error: 4048.627015942844

# %%
residuals = y_test-predictions
sns.distplot(residuals, bins=30)
# Out:
# C:\Users\SAJID\AppData\Local\Temp\ipykernel_7844\339810671.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, bins=30)
# <Axes: xlabel='price', ylabel='Density'>

# %%
import pylab 
import scipy.stats as stats

stats.probplot(residuals, dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# # Summary:
# #### Most Positive Impact:
# - enginesize has the highest positive correlation (0.874), indicating it has the strongest positive effect on car prices.
# #### Most Negative Impact:
# - highwaympg has the highest negative correlation (-0.697), suggesting that higher highway miles per gallon are associated with lower car prices.
# # Interpretation:
# #### Positive Variables:
# -Higher values in enginesize, curbweight, horsepower, carwidth, carlength, wheelbase, and boreratio are likely to lead to higher car prices.
# #### Negative Variables:
# -Higher values in citympg and highwaympg may indicate a less expensive car, potentially because they represent fuel efficiency.
# This analysis can help the car company understand which features to focus on when entering a new market or designing new models.
