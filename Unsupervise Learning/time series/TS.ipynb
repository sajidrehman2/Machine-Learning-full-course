# %% [markdown]
# # Time Series  Data

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('SaleData.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderDate     52 non-null     object
#  1   Region        52 non-null     object
#  2   Manager       52 non-null     object
#  3   SalesMan      52 non-null     object
#  4   Item          52 non-null     object
#  5   Units         52 non-null     int64
#  6    Unit_price   52 non-null     object
#  7   Sale_amt      52 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 3.4+ KB

# %%
data.OrderDate = pd.to_datetime(data.OrderDate)
# Out:
# C:\Users\Nasir Hussain\AppData\Local\Temp\ipykernel_15224\713737600.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data.OrderDate = pd.to_datetime(data.OrderDate)

# %%
# data = data.set_index('OrderDate')
data
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0  2019-08-07  Central  Hermann     Shelli   Video Games     42       58.50
# 1  2019-08-24     West  Timothy    Stephen          Desk      3      125.00
# 2  2019-09-10  Central  Timothy      David    Television      7    1,198.00
# 3  2018-01-06     East   Martha  Alexander    Television     95    1,198.00
# 4  2018-01-23  Central  Hermann     Shelli  Home Theater     50      500.00
# 5  2018-02-09  Central  Hermann       Luis    Television     36    1,198.00
# 6  2018-02-26  Central  Timothy      David    Cell Phone     27      225.00
# 7  2018-03-15     West  Timothy    Stephen    Television     56    1,198.00
# 8  2018-04-01     East   Martha  Alexander  Home Theater     60      500.00
# 9  2018-04-18  Central   Martha     Steven    Television     75    1,198.00
# 10 2018-05-05  Central  Hermann       Luis    Television     90    1,198.00
# 11 2018-05-22     West  Douglas    Michael    Television     32    1,198.00
# 12 2018-06-08     East   Martha  Alexander  Home Theater     60      500.00
# 13 2018-06-25  Central  Hermann      Sigal    Television     90    1,198.00
# 14 2018-07-12     East   Martha      Diana  Home Theater     29      500.00
# 15 2018-07-29     East  Douglas      Karen  Home Theater     81      500.00
# 16 2018-08-15     East   Martha  Alexander    Television     35    1,198.00
# 17 2018-09-01  Central  Douglas       John          Desk      2      125.00
# 18 2018-09-18     East   Martha  Alexander   Video Games     16       58.50
# 19 2018-10-05  Central  Hermann      Sigal  Home Theater     28      500.00
# 20 2018-10-22     East   Martha  Alexander    Cell Phone     64      225.00
# 21 2018-11-08     East  Douglas      Karen    Cell Phone     15      225.00
# 22 2018-11-25  Central  Hermann     Shelli   Video Games     96       58.50
# 23 2018-12-12  Central  Douglas       John    Television     67    1,198.00
# 24 2018-12-29     East  Douglas      Karen   Video Games     74       58.50
# 25 2019-01-15  Central  Timothy      David  Home Theater     46      500.00
# 26 2019-02-01  Central  Douglas       John  Home Theater     87      500.00
# 27 2019-02-18     East   Martha  Alexander  Home Theater      4      500.00
# 28 2019-03-07     West  Timothy    Stephen  Home Theater      7      500.00
# 29 2019-03-24  Central  Hermann       Luis   Video Games     50       58.50
# 30 2019-04-10  Central   Martha     Steven    Television     66    1,198.00
# 31 2019-04-27     East   Martha      Diana    Cell Phone     96      225.00
# 32 2019-05-14  Central  Timothy      David    Television     53    1,198.00
# 33 2019-05-31  Central  Timothy      David  Home Theater     80      500.00
# 34 2019-06-17  Central  Hermann     Shelli          Desk      5      125.00
# 35 2019-07-04     East   Martha  Alexander   Video Games     62       58.50
# 36 2019-07-21  Central  Hermann      Sigal   Video Games     55       58.50
# 37 2019-08-07  Central  Hermann     Shelli   Video Games     42       58.50
# 38 2019-08-24     West  Timothy    Stephen          Desk      3      125.00
# 39 2019-09-10  Central  Timothy      David    Television      7    1,198.00
# 40 2019-09-27     West  Timothy    Stephen    Cell Phone     76      225.00
# 41 2019-10-14     West  Douglas    Michael  Home Theater     57      500.00
# 42 2019-10-31  Central   Martha     Steven    Television     14    1,198.00
# 43 2019-11-17  Central  Hermann       Luis  Home Theater     11      500.00
# 44 2019-12-04  Central  Hermann       Luis  Home Theater     94      500.00
# 45 2019-12-21  Central   Martha     Steven  Home Theater     28      500.00
# 46 2019-04-27     East   Martha      Diana    Cell Phone     96      225.00
# 47 2019-02-01  Central  Douglas       John  Home Theater     87      500.00
# 48 2019-03-24  Central  Hermann       Luis   Video Games     50       58.50
# 49 2019-04-10  Central   Martha     Steven    Television     66    1,198.00
# 50 2019-04-27     East   Martha      Diana    Cell Phone     96      225.00
# 51 2019-05-14  Central  Timothy      David    Television     53    1,198.00
#
#         Sale_amt
# 0      2,457.00
# 1        375.00
# 2      8,386.00
# 3    113,810.00
# 4     25,000.00
# 5     43,128.00
# 6      6,075.00
# 7     67,088.00
# 8     30,000.00
# 9     89,850.00
# 10   107,820.00
# 11    38,336.00
# 12    30,000.00
# 13   107,820.00
# 14    14,500.00
# 15    40,500.00
# 16    41,930.00
# 17       250.00
# 18       936.00
# 19    14,000.00
# 20    14,400.00
# 21     3,375.00
# 22     5,616.00
# 23    80,266.00
# 24     4,329.00
# 25    23,000.00
# 26    43,500.00
# 27     2,000.00
# 28     3,500.00
# 29     2,925.00
# 30    79,068.00
# 31    21,600.00
# 32    63,494.00
# 33    40,000.00
# 34       625.00
# 35     3,627.00
# 36     3,217.50
# 37     2,457.00
# 38       375.00
# 39     8,386.00
# 40    17,100.00
# 41    28,500.00
# 42    16,772.00
# 43     5,500.00
# 44    47,000.00
# 45    14,000.00
# 46    21,600.00
# 47    43,500.00
# 48     2,925.00
# 49    79,068.00
# 50    21,600.00
# 51    63,494.00

# %%
data.index
# Out:
# RangeIndex(start=0, stop=52, step=1)

# %%
data.loc['2018-4':'2019-4']
# Out:
# Empty DataFrame
# Columns: [OrderDate, Region, Manager, SalesMan, Item, Units,  Unit_price , Sale_amt]
# Index: []

# %%
data.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0 2019-08-07  Central  Hermann     Shelli   Video Games     42       58.50
# 1 2019-08-24     West  Timothy    Stephen          Desk      3      125.00
# 2 2019-09-10  Central  Timothy      David    Television      7    1,198.00
# 3 2018-01-06     East   Martha  Alexander    Television     95    1,198.00
# 4 2018-01-23  Central  Hermann     Shelli  Home Theater     50      500.00
#
#        Sale_amt
# 0     2,457.00
# 1       375.00
# 2     8,386.00
# 3   113,810.00
# 4    25,000.00

# %%
data.loc['2018-11-08':'2019-12-04']
# Out:
# Empty DataFrame
# Columns: [OrderDate, Region, Manager, SalesMan, Item, Units,  Unit_price , Sale_amt]
# Index: []

# %%
data.loc['2019-08-07':]
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 21 2018-11-08     East  Douglas      Karen    Cell Phone     15      225.00
# 22 2018-11-25  Central  Hermann     Shelli   Video Games     96       58.50
# 23 2018-12-12  Central  Douglas       John    Television     67    1,198.00
# 24 2018-12-29     East  Douglas      Karen   Video Games     74       58.50
# 25 2019-01-15  Central  Timothy      David  Home Theater     46      500.00
# 26 2019-02-01  Central  Douglas       John  Home Theater     87      500.00
# 27 2019-02-18     East   Martha  Alexander  Home Theater      4      500.00
# 28 2019-03-07     West  Timothy    Stephen  Home Theater      7      500.00
# 29 2019-03-24  Central  Hermann       Luis   Video Games     50       58.50
# 30 2019-04-10  Central   Martha     Steven    Television     66    1,198.00
# 31 2019-04-27     East   Martha      Diana    Cell Phone     96      225.00
# 32 2019-05-14  Central  Timothy      David    Television     53    1,198.00
# 33 2019-05-31  Central  Timothy      David  Home Theater     80      500.00
# 34 2019-06-17  Central  Hermann     Shelli          Desk      5      125.00
# 35 2019-07-04     East   Martha  Alexander   Video Games     62       58.50
# 36 2019-07-21  Central  Hermann      Sigal   Video Games     55       58.50
# 37 2019-08-07  Central  Hermann     Shelli   Video Games     42       58.50
# 38 2019-08-24     West  Timothy    Stephen          Desk      3      125.00
# 39 2019-09-10  Central  Timothy      David    Television      7    1,198.00
# 40 2019-09-27     West  Timothy    Stephen    Cell Phone     76      225.00
# 41 2019-10-14     West  Douglas    Michael  Home Theater     57      500.00
# 42 2019-10-31  Central   Martha     Steven    Television     14    1,198.00
# 43 2019-11-17  Central  Hermann       Luis  Home Theater     11      500.00
# 44 2019-12-04  Central  Hermann       Luis  Home Theater     94      500.00
# 45 2019-12-21  Central   Martha     Steven  Home Theater     28      500.00
# 46 2019-04-27     East   Martha      Diana    Cell Phone     96      225.00
# 47 2019-02-01  Central  Douglas       John  Home Theater     87      500.00
# 48 2019-03-24  Central  Hermann       Luis   Video Games     50       58.50
# 49 2019-04-10  Central   Martha     Steven    Television     66    1,198.00
# 50 2019-04-27     East   Martha      Diana    Cell Phone     96      225.00
# 51 2019-05-14  Central  Timothy      David    Television     53    1,198.00
#
#        Sale_amt
# 21    3,375.00
# 22    5,616.00
# 23   80,266.00
# 24    4,329.00
# 25   23,000.00
# 26   43,500.00
# 27    2,000.00
# 28    3,500.00
# 29    2,925.00
# 30   79,068.00
# 31   21,600.00
# 32   63,494.00
# 33   40,000.00
# 34      625.00
# 35    3,627.00
# 36    3,217.50
# 37    2,457.00
# 38      375.00
# 39    8,386.00
# 40   17,100.00
# 41   28,500.00
# 42   16,772.00
# 43    5,500.00
# 44   47,000.00
# 45   14,000.00
# 46   21,600.00
# 47   43,500.00
# 48    2,925.00
# 49   79,068.00
# 50   21,600.00
# 51   63,494.00

# %% [raw]
# Creating time series with specific frequencies
# • Date offsets
# • Representation of differences in time with timedelta
# • Durations of time with Period objects
# • Calendars
# • Time zones
# • Shifting and lagging
# • Up and down sampling
# • Time series moving-window operations

# %%
from datetime import datetime

# %%
date = datetime(2014, 12, 15)
date
# Out:
# datetime.datetime(2014, 12, 15, 0, 0)

# %%
date.year
# Out:
# 2014

# %%
date.month
# Out:
# 12

# %%
date.day
# Out:
# 15

# %%
new_date = datetime(2014, 12, 15, 17, 30)

# %%
new_date
# Out:
# datetime.datetime(2014, 12, 15, 17, 30)

# %%
new_date.hour
# Out:
# 17

# %%
new_date.minute
# Out:
# 30

# %%
new_date = datetime(2014, 13, 15)
new_date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 new_date = datetime(2014, 13, 15)
#       2 new_date
#
# ValueError: month must be in 1..12

# %%
new_date = datetime(2014, 12, 22,23,59)
new_date

# %%
today = datetime.now()
today
# Out:
# datetime.datetime(2024, 10, 6, 11, 53, 21, 279275)

# %%
today.date()
# Out:
# datetime.date(2024, 10, 6)

# %%
today.time()
# Out:
# datetime.time(11, 53, 21, 279275)

# %% [markdown]
# # Timestamp objects

# %%
import pandas as pd
pd.Timestamp('2014-11-30')
# Out:
# Timestamp('2014-11-30 00:00:00')

# %%
pd.Timestamp('2014-12-15 17:30')
# Out:
# Timestamp('2014-12-15 17:30:00')

# %%
pd.Timestamp('17:30')
# Out:
# Timestamp('2024-10-06 17:30:00')

# %%
pd.Timestamp("now")
# Out:
# Timestamp('2024-10-06 11:53:24.317396')

# %% [markdown]
# # Timedelta
# - A difference between two pandas Timestamp objects is represented by a timedelta
#   object, which is a representation of an exact difference in time.
# - These are common as results of determining the duration between two dates or to calculate the date at a
#   specific interval of time from another date and/or time.

# %%
today = datetime(2023, 9, 12)
today
# Out:
# datetime.datetime(2023, 9, 12, 0, 0)

# %%
tomorrow = today + pd.Timedelta(days=1)
tomorrow
# Out:
# datetime.datetime(2023, 9, 13, 0, 0)

# %%
tomorrow = today + pd.Timedelta(days=10)
tomorrow
# Out:
# datetime.datetime(2023, 9, 22, 0, 0)

# %%
nextmonth_today = today + pd.Timedelta(days=30)
nextmonth_today
# Out:
# datetime.datetime(2023, 10, 12, 0, 0)

# %%
date1 = datetime(2023, 9, 10)
date2 = datetime(2023, 9, 1)

date1 - date2
# Out:
# datetime.timedelta(days=9)

# %% [markdown]
# # Introducing time-series data

# %% [markdown]
# ## DatetimeIndex

# %%
import numpy as np

# %%
series = pd.Series([1,2,3,4], index=["Apple","Bat","Cat","Dog"])
series
# Out:
# Apple    1
# Bat      2
# Cat      3
# Dog      4
# dtype: int64

# %%
dates = [   datetime(2014, 8, 1), datetime(2014, 8, 2),datetime(2014, 7, 2)]
dates
# Out:
# [datetime.datetime(2014, 8, 1, 0, 0),
#  datetime.datetime(2014, 8, 2, 0, 0),
#  datetime.datetime(2014, 7, 2, 0, 0)]

# %%
ts = pd.Series([10000, 25000,4500], dates)
ts
# Out:
# 2014-08-01    10000
# 2014-08-02    25000
# 2014-07-02     4500
# dtype: int64

# %%
ts.index
# Out:
# DatetimeIndex(['2014-08-01', '2014-08-02', '2014-07-02'], dtype='datetime64[ns]', freq=None)

# %%
ts.values
# Out:
# array([10000, 25000,  4500], dtype=int64)

# %%
series.index
# Out:
# Index(['Apple', 'Bat', 'Cat', 'Dog'], dtype='object')

# %%
series.values
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %% [markdown]
# # Converting a string into date
#    ### - using pd.to_datetime

# %%
pd.to_datetime('2023-1-1')
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
dti = pd.to_datetime(
                    ['Aug 1, 2014',
                      '2014-08-02',
                      '2014.8.3',
                       None,]
                    )
dti
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 dti = pd.to_datetime(
#       2                     ['Aug 1, 2014',
#       3                       '2014-08-02',
#       4                       '2014.8.3',
#       5                        None,]
#       6                     )
#       7 dti
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1082, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1080         result = _convert_and_box_cache(argc, cache_array)
#    1081     else:
# -> 1082         result = convert_listlike(argc, format)
#    1083 else:
#    1084     result = convert_listlike(np.array([arg]), format)[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslibs\strptime.pyx:530, in pandas._libs.tslibs.strptime.array_strptime()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslibs\strptime.pyx:351, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "2014-08-02" doesn't match format "%b %d, %Y", at position 1. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
pd.to_datetime(['Aug 1, 2014', 'Augg 1, 2014','2023.13.21'],errors='coerce')

# %% [markdown]
# # Random date time and values
#
# ### using date range

# %%
np.random.seed(123456)

periods1 = pd.date_range('8/1/2014', periods=100)
periods2 = pd.date_range('2014', periods=100)

date_series1 = pd.Series(np.random.randn(100), index=periods1)
date_series2 = pd.Series(np.random.randn(100), index=periods2)

# %%
date_series1
# Out:
# 2014-08-01    0.469112
# 2014-08-02   -0.282863
# 2014-08-03   -1.509059
# 2014-08-04   -1.135632
# 2014-08-05    1.212112
#                 ...
# 2014-11-04   -1.369849
# 2014-11-05   -0.954208
# 2014-11-06    1.462696
# 2014-11-07   -1.743161
# 2014-11-08   -0.826591
# Freq: D, Length: 100, dtype: float64

# %%
date_series2
# Out:
# 2014-01-01   -0.345352
# 2014-01-02    1.314232
# 2014-01-03    0.690579
# 2014-01-04    0.995761
# 2014-01-05    2.396780
#                 ...
# 2014-04-06    0.227371
# 2014-04-07   -0.496922
# 2014-04-08    0.306389
# 2014-04-09   -2.290613
# 2014-04-10   -1.134623
# Freq: D, Length: 100, dtype: float64

# %%
date_series1['2014':'2014']
# Out:
# 2014-08-01    0.469112
# 2014-08-02   -0.282863
# 2014-08-03   -1.509059
# 2014-08-04   -1.135632
# 2014-08-05    1.212112
#                 ...
# 2014-11-04   -1.369849
# 2014-11-05   -0.954208
# 2014-11-06    1.462696
# 2014-11-07   -1.743161
# 2014-11-08   -0.826591
# Freq: D, Length: 100, dtype: float64

# %% [markdown]
# # Creating time-series data with specific frequencies

# %%
np.random.seed(123456)


by_hours = pd.Series(np.random.randn(129600),pd.date_range('2014-08-01','2014-10-29 23:59',freq='T'))

# %%
by_hours
# Out:
# 2014-08-01 00:00:00    0.469112
# 2014-08-01 00:01:00   -0.282863
# 2014-08-01 00:02:00   -1.509059
# 2014-08-01 00:03:00   -1.135632
# 2014-08-01 00:04:00    1.212112
#                          ...
# 2014-10-29 23:55:00   -0.563029
# 2014-10-29 23:56:00    1.180497
# 2014-10-29 23:57:00    1.850604
# 2014-10-29 23:58:00   -1.589660
# 2014-10-29 23:59:00    0.266429
# Freq: T, Length: 129600, dtype: float64

# %%
2160*60
# Out:
# 129600

# %%
by_hours['2014-08-01 05:00':'2014-08-01 10:00']
# Out:
# 2014-08-01 05:00:00   -1.106952
# 2014-08-01 05:01:00   -0.937731
# 2014-08-01 05:02:00   -1.537770
# 2014-08-01 05:03:00    0.555759
# 2014-08-01 05:04:00   -2.277282
#                          ...
# 2014-08-01 09:56:00    0.202636
# 2014-08-01 09:57:00   -0.016217
# 2014-08-01 09:58:00   -0.176382
# 2014-08-01 09:59:00   -1.970108
# 2014-08-01 10:00:00   -1.044208
# Freq: T, Length: 301, dtype: float64

# %% [raw]
# Alias Description
#             B Business day frequency
#             C Custom business day frequency
#             D Calendar day frequency (the default)
#             W Weekly frequency
#             M Month end frequency
#             BM Business month end frequency
#             CBM Custom business month end frequency
#             MS Month start frequency
#             BMS Business month start frequency
#             CBMS Custom business month start frequency
#             Q Quarter end frequency
#             BQ Business quarter frequency
#             QS Quarter start frequency
#             BQS Business quarter start frequency
#             A Year end frequency
#             BA Business year-end frequency
#             AS Year start frequency
#             BAS Business year start frequency
#             H Hourly frequency
#             T Minute-by-minute frequency
#             S Second-by-second frequency
#             L Milliseconds
#             U Microseconds

# %%
days = pd.date_range('2023-08-29', '2023-09-05', freq='B')
days
# Out:
# DatetimeIndex(['2023-08-29', '2023-08-30', '2023-08-31', '2023-09-01',
#                '2023-09-04', '2023-09-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
days = pd.date_range('2023-01-01', '2023-12-31', freq='W')
days
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-08', '2023-01-15', '2023-01-22',
#                '2023-01-29', '2023-02-05', '2023-02-12', '2023-02-19',
#                '2023-02-26', '2023-03-05', '2023-03-12', '2023-03-19',
#                '2023-03-26', '2023-04-02', '2023-04-09', '2023-04-16',
#                '2023-04-23', '2023-04-30', '2023-05-07', '2023-05-14',
#                '2023-05-21', '2023-05-28', '2023-06-04', '2023-06-11',
#                '2023-06-18', '2023-06-25', '2023-07-02', '2023-07-09',
#                '2023-07-16', '2023-07-23', '2023-07-30', '2023-08-06',
#                '2023-08-13', '2023-08-20', '2023-08-27', '2023-09-03',
#                '2023-09-10', '2023-09-17', '2023-09-24', '2023-10-01',
#                '2023-10-08', '2023-10-15', '2023-10-22', '2023-10-29',
#                '2023-11-05', '2023-11-12', '2023-11-19', '2023-11-26',
#                '2023-12-03', '2023-12-10', '2023-12-17', '2023-12-24',
#                '2023-12-31'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
days = pd.date_range('2023-01-01', '2023-12-31', freq='M')
days
# Out:
# DatetimeIndex(['2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
days = pd.date_range('2023-01-01', '2023-12-31', freq='MS')
days
# Out:
# DatetimeIndex(['2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01',
#                '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
days = pd.date_range('2023-01-01', '2023-12-31', freq='BM')
days
# Out:
# DatetimeIndex(['2023-01-31', '2023-02-28', '2023-03-31', '2023-04-28',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-29', '2023-10-31', '2023-11-30', '2023-12-29'],
#               dtype='datetime64[ns]', freq='BM')

# %%
days = pd.date_range('2023-01-01', '2023-12-31', freq='QS')
days
# Out:
# DatetimeIndex(['2023-01-01', '2023-04-01', '2023-07-01', '2023-10-01'], dtype='datetime64[ns]', freq='QS-JAN')

# %%
# periods will use the frequency as the increment
pd.date_range('2014-08-01 12:10:01', freq='S', periods=10)
# Out:
# DatetimeIndex(['2014-08-01 12:10:01', '2014-08-01 12:10:02',
#                '2014-08-01 12:10:03', '2014-08-01 12:10:04',
#                '2014-08-01 12:10:05', '2014-08-01 12:10:06',
#                '2014-08-01 12:10:07', '2014-08-01 12:10:08',
#                '2014-08-01 12:10:09', '2014-08-01 12:10:10'],
#               dtype='datetime64[ns]', freq='S')

# %%
# get all business days between and inclusive of these two dates
dti = pd.date_range('2014-08-29', '2014-09-05', freq='B')
dti.values
# Out:
# array(['2014-08-29T00:00:00.000000000', '2014-09-01T00:00:00.000000000',
#        '2014-09-02T00:00:00.000000000', '2014-09-03T00:00:00.000000000',
#        '2014-09-04T00:00:00.000000000', '2014-09-05T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
dti.freq

# %% [markdown]
# # Manipulating time-series data

# %% [markdown]
# We will now examine several common operations that are performed on time-series
# data.
#
# These operations entail realigning data, changing the frequency of the samples
# and their values, and calculating aggregate results on continuously moving subsets
# of the data to determine the behavior of the values in the data as time changes. We
# will examine each of the following:
#
# • Shifting and lagging values to calculate percentage changes
#
# • Changing the frequency of the data in the time series
#
# • Up and down sampling of the intervals and values in the time series
#
# • Performing rolling-window calculations

# %% [markdown]
# ## Shifting and Lagging

# %%
# create a Series to work with
import numpy as np
np.random.seed(123456)
ts = pd.Series([1, 2, 2.5, 1.5, 0.5], pd.date_range('2014-08-01', periods=5))
ts
# Out:
# 2014-08-01    1.0
# 2014-08-02    2.0
# 2014-08-03    2.5
# 2014-08-04    1.5
# 2014-08-05    0.5
# Freq: D, dtype: float64

# %%
# shift forward one day
ts.shift(2)
# Out:
# 2014-08-01    NaN
# 2014-08-02    NaN
# 2014-08-03    1.0
# 2014-08-04    2.0
# 2014-08-05    2.5
# Freq: D, dtype: float64

# %%
# lag two days
ts.shift(-1)
# Out:
# 2014-08-01    2.0
# 2014-08-02    2.5
# 2014-08-03    1.5
# 2014-08-04    0.5
# 2014-08-05    NaN
# Freq: D, dtype: float64

# %%
# calculate daily percentage change
ts / ts.shift(1)
# Out:
# 2014-08-01         NaN
# 2014-08-02    2.000000
# 2014-08-03    1.250000
# 2014-08-04    0.600000
# 2014-08-05    0.333333
# Freq: D, dtype: float64

# %% [markdown]
# # Up and down resampling

# %%
# calculate a random walk five days long at one second intervals
# these many items will be needed
count = 24 * 60 * 60 * 5
count
# Out:
# 432000

# %%
# create a series of values
np.random.seed(123456)
values = np.random.randn(count)

# %%
ws = pd.Series(values)
ws
# Out:
# 0         0.469112
# 1        -0.282863
# 2        -1.509059
# 3        -1.135632
# 4         1.212112
#             ...
# 431995   -1.731289
# 431996   -0.477632
# 431997   -0.849151
# 431998   -0.255618
# 431999    1.244068
# Length: 432000, dtype: float64

# %%
w_seconds= pd.Series(values,pd.date_range('2023-1-1', periods=432000, freq='S'))
w_seconds
# Out:
# 2023-01-01 00:00:00    0.469112
# 2023-01-01 00:00:01   -0.282863
# 2023-01-01 00:00:02   -1.509059
# 2023-01-01 00:00:03   -1.135632
# 2023-01-01 00:00:04    1.212112
#                          ...
# 2023-01-05 23:59:55   -1.731289
# 2023-01-05 23:59:56   -0.477632
# 2023-01-05 23:59:57   -0.849151
# 2023-01-05 23:59:58   -0.255618
# 2023-01-05 23:59:59    1.244068
# Freq: S, Length: 432000, dtype: float64

# %%
w_hours =w_seconds.resample(rule="h").mean()

# %%
# calculate the walk
walk = w_hours.cumsum()
walk.plot()
# Out:
# <Axes: >

# %%
w_days = w_seconds.resample(rule='D').max()
w_days
# Out:
# 2023-01-01    3.917561
# 2023-01-02    4.377494
# 2023-01-03    4.460343
# 2023-01-04    4.196487
# 2023-01-05    4.523934
# Freq: D, dtype: float64

# %%
walk = w_days.cumsum()
walk.plot()
# Out:
# <Axes: >

# %%
# patch the index
walk.index = pd.date_range('2014-08-01', periods=count, freq="S")
walk
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 2
#       1 # patch the index
# ----> 2 walk.index = pd.date_range('2014-08-01', periods=count, freq="S")
#       3 walk
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
#     726 This is called from the cython code when we set the `index` attribute
#     727 directly, e.g. `series.index = [1, 2, 3]`.
#     728 """
#     729 labels = ensure_index(labels)
# --> 730 self._mgr.set_axis(axis, labels)
#     731 self._clear_item_cache()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:225, in BaseBlockManager.set_axis(self, axis, new_labels)
#     223 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224     # Caller is responsible for ensuring we have an Index object.
# --> 225     self._validate_set_axis(axis, new_labels)
#     226     self.axes[axis] = new_labels
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 5 elements, new values have 432000 elements

# %%
# resample to minute intervals
# walk.resample("1Min").mean().plot()

# %%
walk.resample("1H",how='mean').plot()

# %% [markdown]
# # Creating time-series charts with .plot()

# %%
# generate a random walk time-series
np.random.seed(123)
s = pd.Series(np.random.randn(1096),
index=pd.date_range('2012-01-01','2014-12-31'))
walk_ts = s.cumsum()

# %%
# this plots the walk - just that easy :)
s.plot()
s.plot(grid=True)
# Out:
# <Axes: >

# %%
walk_ts.plot()
walk_ts.plot(grid=True)
# Out:
# <Axes: >

# %% [markdown]
# # Time-series moving-window operations

# %% [raw]
# pandas provides a number of functions to compute moving (also known as rolling)
# statistics. In a rolling window, pandas computes the statistic on a window of data
# represented by a particular period of time. The window is then rolled along a certain
# interval, and the statistic is continually calculated on each window as long as the
# window fits within the dates of the time series.
# pandas provides direct support for rolling windows with the following functions:

# %% [raw]
# Function Description
# rolling_mean The mean of values in the window
# rolling_std The standard deviation of values in the window
# rolling_var The variance of values
# rolling_min The minimum of values in the window
# rolling_max The maximum of values in the window
# rolling_cov The covariance of values
# rolling_quantile Moving window score at percentile/sample quantile
# rolling_corr The correlation of values in the window
# rolling_median The median of values in the window
# rolling_sum The sum of values in the window
# rolling_apply The application of a user function to values in the window
# rolling_count The number of non-NaN values in a window
# rolling_skew The skewedness of the values in the window
# rolling_kurt The kurtosis of values in the window

# %% [raw]
# As a practical example, a rolling mean is commonly used to smooth out short-term
# fluctuations and highlight longer-term trends in data and is used quite commonly in
# financial time-series analysis

# %%
import numpy as np
import pandas as pd

#make this example reproducible
np.random.seed(0)

#create dataset
period = np.arange(1, 101, 1)
leads = np.random.uniform(1, 20, 100)
sales = 60 + 2*period + np.random.normal(loc=0, scale=.5*period, size=100)
df = pd.DataFrame({'period': period, 'leads': leads, 'sales': sales})

#view first 10 rows
df
# Out:
#     period      leads       sales
# 0        1  11.427457   61.417425
# 1        2  14.588598   64.900826
# 2        3  12.452504   66.698494
# 3        4  11.352780   64.927513
# 4        5   9.049441   73.720630
# ..     ...        ...         ...
# 95      96   4.480636  284.716537
# 96      97  12.143746  215.034631
# 97      98   1.382043  222.212061
# 98      99  16.749861  235.451141
# 99     100   1.089214  260.873958
#
# [100 rows x 3 columns]

# %%
df['sales'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # We can use the following syntax to create a new column that contains the rolling mean of ‘sales’ for the previous 5 periods:

# %%
#find rolling mean of previous 5 sales periods
df['rolling_sales_5'] = df['sales'].rolling(5,min_periods=1).mean()

#view first 10 rows
df
# Out:
#     period      leads       sales  rolling_sales_5
# 0        1  11.427457   61.417425        61.417425
# 1        2  14.588598   64.900826        63.159126
# 2        3  12.452504   66.698494        64.338915
# 3        4  11.352780   64.927513        64.486064
# 4        5   9.049441   73.720630        66.332978
# ..     ...        ...         ...              ...
# 95      96   4.480636  284.716537       249.499179
# 96      97  12.143746  215.034631       240.773811
# 97      98   1.382043  222.212061       228.047698
# 98      99  16.749861  235.451141       231.657567
# 99     100   1.089214  260.873958       243.657666
#
# [100 rows x 4 columns]

# %%
df['sales'].plot()
df['rolling_sales_5'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # We can manually verify that the rolling mean sales displayed for period 5 is the mean of the previous 5 periods:
#
# Rolling mean at period 5: (61.417+64.900+66.698+64.927+73.720)/5 = 66.33
#
# We can use similar syntax to calculate the rolling mean of multiple columns:

# %%
#find rolling mean of previous 5 leads periods 
 

#find rolling mean of previous 5 leads periods
df['rolling_sales_5'] = df['sales'].rolling(5).mean()
df['rolling_sales_10'] = df['sales'].rolling(10).mean()
df['rolling_sales_30'] = df['sales'].rolling(30).mean()
df['rolling_sales_15'] = df['sales'].rolling(15).mean()

#view first 10 rows
df
# Out:
#     period      leads       sales  rolling_sales_5  rolling_sales_10  \
# 0        1  11.427457   61.417425              NaN               NaN
# 1        2  14.588598   64.900826              NaN               NaN
# 2        3  12.452504   66.698494              NaN               NaN
# 3        4  11.352780   64.927513              NaN               NaN
# 4        5   9.049441   73.720630        66.332978               NaN
# ..     ...        ...         ...              ...               ...
# 95      96   4.480636  284.716537       249.499179        243.504542
# 96      97  12.143746  215.034631       240.773811        245.958942
# 97      98   1.382043  222.212061       228.047698        251.377141
# 98      99  16.749861  235.451141       231.657567        245.835522
# 99     100   1.089214  260.873958       243.657666        246.496676
#
#     rolling_sales_30  rolling_sales_15
# 0                NaN               NaN
# 1                NaN               NaN
# 2                NaN               NaN
# 3                NaN               NaN
# 4                NaN               NaN
# ..               ...               ...
# 95        221.271585        245.430730
# 96        222.992058        239.558984
# 97        222.599841        236.679724
# 98        225.361506        236.931323
# 99        227.929153        242.461655
#
# [100 rows x 7 columns]

# %% [markdown]
# # We can also create a quick line plot using Matplotlib to visualize the raw sales compared to the rolling mean of sales:
#
# import matplotlib.pyplot as plt
# plt.plot(df['rolling_sales_5'], label='Rolling Mean')
# plt.plot(df['sales'], label='Raw Data')
# plt.legend()
# plt.ylabel('Sales')
# plt.xlabel('Period')
# plt.show()

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(14,6))
plt.plot(df['rolling_sales_15'], label='Rolling Mean15') 
# plt.plot(df['rolling_sales_30'], label='Rolling Mean30')
# plt.plot(df['rolling_sales_5'], label='Rolling Mean5')
plt.plot(df['rolling_sales_10'], label='Rolling Mean10')

plt.plot(df['sales'], label='Raw Data') 
plt.legend() 
plt.ylabel('Sales') 
plt.xlabel('Period') 
plt.show()

# %% [markdown]
# # Python | ARIMA Model for Time Series Forecasting

# %% [markdown]
# ### A Time Series is defined as a series of data points indexed in time order. The time order can be daily, monthly, or even yearly. Given below is an example of a Time Series that illustrates the number of passengers of an airline per month from the year 1949 to 1960.

# %% [markdown]
# ![aripassenger.png](attachment:aripassenger.png)

# %% [markdown]
# # Time Series Forecasting
# Time Series forecasting is the process of using a statistical model to predict future values of a time series based on past results.

# %% [markdown]
# - To predict the number of incoming or churning customers.
# - To explaining seasonal patterns in sales.
# - To detect unusual events and estimate the magnitude of their effect.
# - To Estimate the effect of a newly launched product on number of sold units.

# %% [markdown]
# # Components of a Time Series:
#
# Trend:
#
# The trend shows a general direction of the time series data over a long period of time. A trend can be increasing(upward), decreasing(downward), or horizontal(stationary).
#
# Seasonality:
#
# The seasonality component exhibits a trend that repeats with respect to timing, direction, and magnitude. Some examples include an increase in water consumption in summer due to hot weather conditions, or an increase in the number of airline passengers during holidays each year.
#
# Cyclical Component:
#
# These are the trends with no set repetition over a particular period of time. A cycle refers to the period of ups and downs, booms and slums of a time series, mostly observed in business cycles. These cycles do not exhibit a seasonal variation but generally occur over a time period of 3 to 12 years depending on the nature of the time series.
# Irregular Variation: These are the fluctuations in the time series data which become evident when trend and cyclical variations are removed. These variations are unpredictable, erratic, and may or may not be random.
#
# ETS Decomposition:
#
# ETS Decomposition is used to separate different components of a time series. The term ETS stands for Error, Trend, and Seasonality.

# %% [markdown]
# # What Are the Limitations of Time Series Analysis?
# Time series has the below-mentioned limitations; we have to take care of those during our data analysis.
#
# - Similar to other models, the missing values are not supported by TSA
# - The data points must be linear in their relationship.
# - Data transformations are mandatory, so they are a little expensive.
# - Models mostly work on Uni-variate data.

# %% [markdown]
# # Data Types of Time Series
#
# Let’s discuss the time series’ data types and their influence. While discussing TS data types, there are two major types – stationary and non-stationary.
#
# - Stationary: A dataset should follow the below thumb rules without having Trend, Seasonality, Cyclical, and Irregularity components of the time series.
#
# - The mean value of them should be completely constant in the data during the analysis.
# - The variance should be constant with respect to the time-frame
# - Covariance measures the relationship between two variables.
# - Non- Stationary: If either the mean-variance or covariance is changing with respect to time, the dataset is called non-stationary.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Methods to Check Stationarity
# During the TSA model preparation workflow, we must assess whether the dataset is stationary or not. This is done using Statistical Tests. There are two tests available to test if the dataset is stationary:
#
# - Augmented Dickey-Fuller (ADF) Test
#
# - Kwiatkowski-Phillips-Schmidt-Shin (KPSS) Test

# %% [markdown]
# # Augmented Dickey-Fuller (ADF) Test or Unit Root Test
# The ADF test is the most popular statistical test. It is done with the following assumptions:
#
# - Null Hypothesis (H0): Series is non-stationary
# - Alternate Hypothesis (HA): Series is stationary
#     - p-value >0.05 Fail to reject (H0)
#     - p-value <= 0.05 Accept (H1)
#
# - Kwiatkowski–Phillips–Schmidt–Shin (KPSS) Test
#         These tests are used for testing a NULL Hypothesis (HO) that will perceive the time series as stationary around a deterministic trend against the alternative of a unit root. Since TSA is looking for Stationary Data for its further analysis, we have to ensure that the dataset is stationary.

# %% [markdown]
# # Converting Non-Stationary Into Stationary
# Let’s discuss quickly how to convert non-stationary to stationary for effective time series modeling. There are three methods available for this conversion
# - detrending,
# - differencing,
# - transformation

# %% [markdown]
# # Detrending
# It involves removing the trend effects from the given dataset and showing only the differences in values from the trend. It always allows cyclical patterns to be identified.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Differencing
# This is a simple transformation of the series into a new time series, which we use to remove the series dependence on time and stabilize the mean of the time series, so trend and seasonality are reduced during this transformation.
#
# Yt= Yt – Yt-1
#
# where
#  - Yt=Value with time
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# # Transformation
# This includes three different methods they are
# - Power Transform,
# - Square Root,
# - and Log Transfer
#
# The most commonly used one is Log Transfer.

# %% [markdown]
# # Moving Average Methodology
# The commonly used time series method is the Moving Average. This method is slick with random short-term variations. Relatively associated with the components of time series.
#
# ## The Moving Average (MA) (or) Rolling Mean:
# The value of MA is calculated by taking average data of the time-series within k periods.
#
# Let’s see the types of moving averages:
#
#  - Simple Moving Average (SMA),
#  - Cumulative Moving Average (CMA)
#  - Exponential Moving Average (EMA)
# ## Simple Moving Average (SMA)
#  - The Simple Moving Average (SMA) calculates the unweighted mean of the previous M or N points. We prefer selecting sliding window data points based on the amount of smoothing, as increasing the value of M or N improves smoothing but reduces accuracy.
#
# To understand better, I will use the air temperature dataset.
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
df_temperature = pd.read_csv('temperatures.csv', encoding='utf-8')
df_temperature.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.30 -0.21 -0.18 -0.27 -0.14 -0.29 -0.24 -0.08 -0.17 -0.16 -0.19
# 1  1881 -0.10 -0.14  0.01 -0.03 -0.04 -0.28 -0.07 -0.03 -0.09 -0.20 -0.26
# 2  1882  0.09  0.08  0.01 -0.20 -0.18 -0.25 -0.11  0.03 -0.01 -0.23 -0.21
# 3  1883 -0.34 -0.42 -0.18 -0.25 -0.26 -0.13 -0.09 -0.14 -0.19 -0.12 -0.21
# 4  1884 -0.18 -0.13 -0.36 -0.36 -0.32 -0.38 -0.35 -0.27 -0.24 -0.22 -0.30
#
#     Dec
# 0 -0.22
# 1 -0.16
# 2 -0.25
# 3 -0.19
# 4 -0.30

# %%
df_temperature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    137 non-null    int64
#  1   Jan     137 non-null    float64
#  2   Feb     137 non-null    float64
#  3   Mar     137 non-null    float64
#  4   Apr     137 non-null    float64
#  5   May     137 non-null    float64
#  6   Jun     137 non-null    float64
#  7   Jul     137 non-null    float64
#  8   Aug     137 non-null    float64
#  9   Sep     137 non-null    float64
#  10  Oct     137 non-null    float64
#  11  Nov     137 non-null    float64
#  12  Dec     137 non-null    float64
# dtypes: float64(12), int64(1)
# memory usage: 14.0 KB

# %%
df_temperature.set_index('Year', inplace=True)

# %%
df_temperature
# Out:
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# Year
# 1880 -0.30 -0.21 -0.18 -0.27 -0.14 -0.29 -0.24 -0.08 -0.17 -0.16 -0.19 -0.22
# 1881 -0.10 -0.14  0.01 -0.03 -0.04 -0.28 -0.07 -0.03 -0.09 -0.20 -0.26 -0.16
# 1882  0.09  0.08  0.01 -0.20 -0.18 -0.25 -0.11  0.03 -0.01 -0.23 -0.21 -0.25
# 1883 -0.34 -0.42 -0.18 -0.25 -0.26 -0.13 -0.09 -0.14 -0.19 -0.12 -0.21 -0.19
# 1884 -0.18 -0.13 -0.36 -0.36 -0.32 -0.38 -0.35 -0.27 -0.24 -0.22 -0.30 -0.30
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2012  0.46  0.49  0.58  0.69  0.76  0.62  0.57  0.63  0.76  0.78  0.75  0.53
# 2013  0.68  0.55  0.66  0.52  0.61  0.65  0.59  0.66  0.78  0.69  0.81  0.67
# 2014  0.73  0.51  0.77  0.78  0.87  0.66  0.57  0.82  0.90  0.85  0.67  0.79
# 2015  0.81  0.86  0.90  0.74  0.78  0.78  0.71  0.78  0.81  1.06  1.04  1.11
# 2016  1.17  1.35  1.30  1.09  0.93  0.76  0.83  0.98  0.87  0.89  0.93  0.81
#
# [137 rows x 12 columns]

# %%
df_temperature['average_temperature'] = df_temperature.mean(axis=1)
# #drop unwanted columns and resetting the datafreame
df_temperature = df_temperature[['average_temperature']]
df_temperature
# Out:
#       average_temperature
# Year
# 1880            -0.204167
# 1881            -0.115833
# 1882            -0.102500
# 1883            -0.210000
# 1884            -0.284167
# ...                   ...
# 2012             0.635000
# 2013             0.655833
# 2014             0.743333
# 2015             0.865000
# 2016             0.992500
#
# [137 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df_temperature)

# %%
# SMA over a period of 10 and 20 years 
df_temperature['SMA_10'] = df_temperature.average_temperature.rolling(10, min_periods=1).mean()
df_temperature['SMA_15'] = df_temperature.average_temperature.rolling(15,min_periods=1).mean()
df_temperature['SMA_5'] = df_temperature.average_temperature.rolling(5,min_periods=1).mean()
df_temperature

# Grean = Avg Air Temp, RED = 10 yrs, ORANG colors for the line plot
colors = ['green', 'red', 'orange','blue']
# # Line plot 
df_temperature.plot(color=colors, linewidth=3, figsize=(12,6))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels =['Average air temperature', '10-years SMA', '15-years SMA', '5-years SMA'], fontsize=14)
plt.title('The yearly average air temperature in city', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Temperature [°C]', fontsize=16)
# Out:
# C:\Users\Nasir Hussain\AppData\Local\Temp\ipykernel_15224\2729215352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['SMA_10'] = df_temperature.average_temperature.rolling(10, min_periods=1).mean()
# C:\Users\Nasir Hussain\AppData\Local\Temp\ipykernel_15224\2729215352.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['SMA_15'] = df_temperature.average_temperature.rolling(15,min_periods=1).mean()
# C:\Users\Nasir Hussain\AppData\Local\Temp\ipykernel_15224\2729215352.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['SMA_5'] = df_temperature.average_temperature.rolling(5,min_periods=1).mean()
# Text(0, 0.5, 'Temperature [°C]')

# %% [markdown]
# # Cumulative Moving Average (CMA)
# The CMA is the unweighted mean of past values till the current time.
# ![image.png](attachment:image.png)

# %%
# CMA Air temperature
df_temperature['CMA'] = df_temperature.average_temperature.expanding().mean()

# green -Avg Air Temp and Orange -CMA
colors = ['green', 'orange']
# line plot
df_temperature[['average_temperature', 'CMA']].plot(color=colors, linewidth=3, figsize=(12,6))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels =['Average Air Temperature', 'CMA'], fontsize=14)
plt.title('The yearly average air temperature in city', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Temperature [°C]', fontsize=16)
# Out:
# C:\Users\Nasir Hussain\AppData\Local\Temp\ipykernel_15224\4099039659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['CMA'] = df_temperature.average_temperature.expanding().mean()
# Text(0, 0.5, 'Temperature [°C]')

# %% [markdown]
# # Exponential Moving Average (EMA)
#
# EMA is mainly used to identify trends and filter out noise. The weight of elements is decreased gradually over time. This means It gives weight to recent data points, not historical ones. Compared with SMA, the EMA is faster to change and more sensitive.
#
# α –>Smoothing Factor.
#
# It has a value between 0,1.
#
# Represents the weighting applied to the very recent period.
#
# Let’s apply the exponential moving averages with a smoothing factor of 0.1 and 0.3 in the given dataset.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# EMA Air Temperature
# Let's smoothing factor - 0.1
df_temperature['EMA_0.1'] = df_temperature.average_temperature.ewm(alpha=0.1, adjust=False).mean()
# Let's smoothing factor  - 0.3
df_temperature['EMA_0.3'] = df_temperature.average_temperature.ewm(alpha=0.1, adjust=False).mean()
df_temperature['EMA_0.5'] = df_temperature.average_temperature.ewm(alpha=0.2, adjust=False).mean()
df_temperature['EMA_1'] = df_temperature.average_temperature.ewm(alpha=1.0, adjust=False).mean()

# green - Avg Air Temp, red- smoothing factor - 0.1, yellow - smoothing factor  - 0.3
colors = ['green', 'red', 'yellow', 'blue','purple']
df_temperature[['average_temperature', 'EMA_0.1', 'EMA_0.3','EMA_0.5','EMA_1']].plot(color=colors, linewidth=3, figsize=(12,6), alpha=0.8)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels=['Average air temperature', 'EMA - alpha=0.1', 'EMA - alpha=0.3','EMA - alpha=0.5','EMA - alpha=1'], fontsize=14)
plt.title('The yearly average air temperature in city', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Temperature [°C]', fontsize=16)
# Out:
# C:\Users\Nasir Hussain\AppData\Local\Temp\ipykernel_15224\797173194.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['EMA_0.1'] = df_temperature.average_temperature.ewm(alpha=0.1, adjust=False).mean()
# C:\Users\Nasir Hussain\AppData\Local\Temp\ipykernel_15224\797173194.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['EMA_0.3'] = df_temperature.average_temperature.ewm(alpha=0.1, adjust=False).mean()
# C:\Users\Nasir Hussain\AppData\Local\Temp\ipykernel_15224\797173194.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['EMA_0.5'] = df_temperature.average_temperature.ewm(alpha=0.2, adjust=False).mean()
# C:\Users\Nasir Hussain\AppData\Local\Temp\ipykernel_15224\797173194.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['EMA_1'] = df_temperature.average_temperature.ewm(alpha=1.0, adjust=False).mean()
# Text(0, 0.5, 'Temperature [°C]')

# %% [markdown]
# # Time Series Analysis in Data Science and Machine Learning
# When dealing with TSA in Data Science and Machine Learning, there are multiple model options are available.
#
# In which the Autoregressive–Moving-Average (ARMA) models with [p, d, and q].
#
#     - P==> autoregressive lags
#     - q== moving average lags
#     - d==> difference in the order
#
# Before we get to know about Arima, first, you should understand the below terms better.
#
#         - Auto-Correlation Function (ACF)
#         - Partial Auto-Correlation Function (PACF)
#         - Auto-Correlation Function (ACF)
#
# ACF indicates how similar a value is within a given time series and the previous value. (OR) It measures the degree of the similarity between a given time series and the lagged version of that time series at the various intervals we observed.
#
# <b>Python Statsmodels library calculates autocorrelation. It identifies a set of trends in the given dataset and the influence of former observed values on the currently observed values.</b>
#
# ## Partial Auto-Correlation (PACF)
# PACF is similar to Auto-Correlation Function and is a little challenging to understand. It always shows the correlation of the sequence with itself with some number of time units per sequence order in which only the direct effect has been shown, and all other intermediary effects are removed from the given time series.

# %%
plot_acf(df_temperature['average_temperature'])
plt.show()

plot_acf(df_temperature['average_temperature'], lags=30)
plt.show()

# %% [markdown]
# # Observation
#
# The previous temperature influences the current temperature, but the significance of that influence decreases and slightly increases from the above visualization along with the temperature with regular time intervals.

# %% [markdown]
# # Types of Auto-Correlation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Interpret ACF and PACF Plots
# ACF	PACF	Perfect ML -Model
# Plot declines gradually	Plot drops instantly	Auto Regressive model.
# Plot drops instantly	Plot declines gradually	Moving Average model
# Plot decline gradually	Plot Decline gradually	ARMA
# Plot drop instantly	Plot drop instantly	You wouldn’t perform any model
# ![image.png](attachment:image.png)

# %% [markdown]
# ####  Remember that both ACF and PACF require stationary time series for analysis.

# %% [markdown]
# # What Is an Auto-Regressive Model?
#
# An auto-regressive model is a simple model that predicts future performance based on past performance.
# It is mainly used for forecasting when there is some correlation between values in a given time series and those that precede and succeed (back and forth).
#
#
# An AR is a Linear Regression model that uses lagged variables as input.
# By indicating the input, the Linear Regression model can be easily built using the scikit-learn library.
# Statsmodels library provides autoregression model-specific functions where you must specify an appropriate lag value and train the model.
# It is provided in the AutoTeg class to get the results using simple steps.
#
#
#  - Creating the model AutoReg()
#  - Call fit() to train it on our dataset.
#  - Returns an AutoRegResults object.
#
# Once fit, make a prediction by calling the predict () function
# The equation for the AR model (Let’s compare Y=mX+c)
#
#              <b>Yt =C+b1 Yt-1+ b2 Yt-2+……+ bp Yt-p+ Ert</b>
#
# ### Key Parameters
#
#         - p=past values
#         - Yt=Function of different past values
#         - Ert=errors in time
#         - C=intercept
#
# Lets’s check whether the given data set or time series is random or not.

# %%
from matplotlib import pyplot
from pandas.plotting import lag_plot
lag_plot(df_temperature,lag=1)
pyplot.show()

# %% [markdown]
# # Observation
#
# it looks random and scattered or unscattered?

# %% [markdown]
# # Implementation of Auto-Regressive Model

# %%
#import libraries
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
from math import sqrt
# load csv as dataset
#series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# split dataset for test and training
X = df_temperature.values

# %%
train, test = X[1:len(X)-7], X[len(X)-7:]

# %%
# Importing required libraries
import numpy as np
import pandas as pd
# import matplotlib.pylot as plt
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Read the AirPassengers dataset
airline = pd.read_csv('AirPassengers.csv',index_col ='Month',parse_dates = True)

# %%
# Print the first five rows of the dataset
airline.head()

# %% [markdown]
# # https://www.statsmodels.org/dev/examples/notebooks/generated/stl_decomposition.html

# %%
# ETS Decomposition
result = seasonal_decompose(airline['Passengers'],model ='multiplicative')

# %%
# ETS plot
result.plot()

# %% [markdown]
# # ARIMA Model for Time Series Forecasting

# %% [markdown]
# #### ARIMA stands for autoregressive integrated moving average model and is specified by three order parameters: (p, d, q).

# %% [markdown]
# AR(p) Autoregression:
#     A regression model that utilizes the dependent relationship between a current observation and observations over a previous period.An auto regressive (AR(p)) component refers to the use of past values in the regression equation for the time series.
#
# I(d) Integration
#     Uses differencing of observations (subtracting an observation from observation at the previous time step) in order to make the time series stationary. Differencing involves the subtraction of the current values of a series with its previous values d number of times.
#
# MA(q) Moving Average
#     A model that uses the dependency between an observation and a residual error from a moving average model applied to lagged observations. A moving average component depicts the error of the model as a combination of previous error terms. The order q represents the number of terms to be included in the model.

# %% [markdown]
# # Types of ARIMA Model

# %% [markdown]
# ARIMA:Non-seasonal Autoregressive Integrated Moving Averages
#
# SARIMA:Seasonal ARIMA
#
# SARIMAX:Seasonal ARIMA with exogenous variables
#
# Pyramid Auto-ARIMA
#
# The ‘auto_arima’ function from the ‘pmdarima’ library helps us to identify the most optimal parameters for an ARIMA model and returns a fitted ARIMA model.

# %%
# To install the library
# !conda install -c conda-forge pmdarima

# %%
from pmdarima import auto_arima

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Fit auto_arima function to AirPassengers dataset
stepwise_fit = auto_arima(airline['Passengers'], start_p = 1, start_q = 1, max_p = 3, max_q = 3, m = 12,
                         start_P = 0, 
                         seasonal = True,
                         d = None, 
                         D = 1, 
                         trace = True,
                         error_action ='ignore',   # we don't want to know if an order does not work
                         suppress_warnings = True,  # we don't want convergence warnings
                         stepwise = True)           # set to stepwise
  
# To print the summary
stepwise_fit.summary()
